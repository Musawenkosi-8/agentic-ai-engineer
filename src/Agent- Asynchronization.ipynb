# %%
import asyncio
import time
from groq import AsyncGroq
from src.config import Config

client = AsyncGroq(api_key=Config.GROQ_API_KEY)

async def ask_agent(expert_type, topic):
    """Specialized Agent Node"""
    print(f"{expert_type} agent is analyzing {topic}...")
    prompt = f"As a {expert_type}, what is the main impact of {topic}?"  
    response = await client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=[{"role": "user", "content": prompt}],
    max_tokens=100)
    return f"{expert_type.upper()}: {response.choices[0].message.content}"

async def run_concurrent_research(topic):
    start_time = time.perf_counter()
    experts = ["Economist", "Technologist", "Ethicist"]

    print(f"Launching {len(experts)} agents concurrently...")

    results = await asyncio.gather(*[ask_agent(expert, topic) for expert in experts]
                                    )
    end_time = time.perf_counter()

    print("\n--- Consolidated Research Report---")

    for r in results:
        print(r)
    print(f"\n Total time with Asyncio: {end_time - start_time:.2f} seconds")

if __name__ == "__main__":
    await run_concurrent_research("Nuclear Fusion")
# Out:
# Launching 3 agents concurrently...
# Economist agent is analyzing Nuclear Fusion...
# Technologist agent is analyzing Nuclear Fusion...
# Ethicist agent is analyzing Nuclear Fusion...
#
# --- Consolidated Research Report---
# ECONOMIST: As an economist, I'll highlight the main impact of nuclear fusion on the economy and society.
#
# **Sustainable Energy Source:**
# Nuclear fusion has the potential to become a nearly limitless, clean, and sustainable energy source. This is because fusion combines isotopes of hydrogen to release energy, just like stars do, but without the production of greenhouse gases, long-lived radioactive waste, or any environmental hazards.
#
# **Energy Abundance:**
# The abundance of nuclear fusion energy can transform the global economy. By
# TECHNOLOGIST: As a Technologist, I'd be excited to discuss the main impact of Nuclear Fusion.
#
# Nuclear Fusion has the potential to revolutionize the world's energy landscape. Here are the main impacts:
#
# 1. **Near-limitless and Clean Energy**: Nuclear Fusion can provide a nearly limitless supply of energy with minimal environmental impact. It releases no greenhouse gas emissions, no long-lived radioactive waste, and no air pollution.
#
# 2. **Reduced CO2 Emissions**: By generating electricity without burning fossil fuels,
# ETHICIST: As an ethicist, I'd like to emphasize the multifaceted nature of nuclear fusion and its potential impacts. Nuclear fusion, the process of combining atomic nuclei to release energy, has been hailed as a game-changer for the world's energy needs. Here are some of the main potential impacts, both positive and negative:
#
# **Positive impacts:**
#
# 1. **Clean energy source:** Nuclear fusion has the potential to be a nearly limitless, clean energy source, producing no greenhouse gas emissions, long-lived
#
#  Total time with Asyncio: 3.24 seconds
